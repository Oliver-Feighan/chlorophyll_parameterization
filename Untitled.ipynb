# %% [markdown]
# # Chlorophyll parameterization

# %%
import numpy as np
import pandas as pd
import json

# %%
def read_results(file_name : str):
    data = open(file_name)
    data = json.load(data)

    return pd.DataFrame.from_dict(data).T
    
def read_parameters():
    return

# %%
read_results("validate_2021_1_28_1552.json")
# Out:
#                        tddft_energy xtb_energy energy_error  \
# step_1_chromophore_01      0.067717  0.0292923    0.0384247
# step_1_chromophore_03      0.069472  0.0318612    0.0376108
# step_1_chromophore_05      0.068697  0.0313011    0.0373959
# step_1_chromophore_10      0.069634  0.0330405    0.0365935
# step_1_chromophore_21      0.068427  0.0318708    0.0365562
# ...                             ...        ...          ...
# step_51_chromophore_18      0.06746   0.032639     0.034821
# step_51_chromophore_19     0.068516  0.0310777    0.0374383
# step_51_chromophore_21     0.067183  0.0302783    0.0369047
# step_51_chromophore_22     0.067402  0.0298246    0.0375774
# step_51_chromophore_26     0.070272  0.0342047    0.0360673
#
#                                                       tddft_dipole  \
# step_1_chromophore_01     [0.305422706, -2.699393089, 0.410750669]
# step_1_chromophore_03    [0.108963122, -2.698943706, -0.009963017]
# ...
