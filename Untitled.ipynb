# %%
import pickle as pkl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import matplotlib 
matplotlib.rcParams.update({'font.size': 22})

# %%
dipole_results = pd.read_pickle("dipole_mags/dipole_mags.pkl")
dipole_results
# Out:
#                  chromophores   set  tddft_energy  xtb_energy  energy_error  \
# 0     step_1001_chromophore_1  test      1.912907    1.898920     -0.013987
# 1    step_1001_chromophore_12  test      1.800987    1.804230      0.003243
# 2    step_1001_chromophore_13  test      1.945561    1.942465     -0.003096
# 3    step_1001_chromophore_15  test      1.872008    1.890991      0.018983
# 4    step_1001_chromophore_16  test      1.826320    1.817899     -0.008421
# ..                        ...   ...           ...         ...           ...
# 502   step_951_chromophore_21  test      1.853668    1.880141      0.026473
# 503   step_951_chromophore_23  test      1.826429    1.823362     -0.003067
# 504   step_951_chromophore_24  test      1.843708    1.833975     -0.009733
# 505    step_951_chromophore_3  test      1.857586    1.835276     -0.022310
# 506    step_951_chromophore_4  test      1.815708    1.778200     -0.037508
#
#      Z_values                               tddft_dipoles  \
# 0   -0.891145    [-0.34950403, 2.653887491, -0.477898847]
# 1    0.202531   [-2.287369813, -1.499455904, 0.193644764]
# 2   -0.199847   [-0.754756204, -2.53537159, -0.019176462]
# 3    1.201564   [-0.54968506, -2.608078035, -0.050338471]
# 4   -0.537836    [-0.947789088, 2.495867441, 0.332799887]
# ..        ...                                         ...
# 502  1.677002   [-2.490853557, 1.063950918, -0.062505406]
# 503 -0.198003   [-0.422365249, -2.610028365, 0.590992657]
# 504 -0.621130    [-2.783375996, 0.034964353, 0.263783579]
# 505 -1.419430  [-0.012588919, -2.812019863, -0.183832072]
# 506 -2.384075     [1.46951434, -2.245793022, 0.454362367]
#
#                                            xtb_dipoles  dipole_errors  \
# 0    [0.36169878382359116, -2.663533076023871, 0.12...       0.352388
# 1    [2.3210436296213315, 1.4547704031717854, -0.04...       0.162745
# 2    [0.7942018025755319, 2.554650398302077, -0.270...       0.293368
# 3    [-0.5191698525715183, -2.6245531989082855, -0....       0.166883
# 4    [-0.9780427503388807, 2.5676113808255963, -0.0...       0.393144
# ..                                                 ...            ...
# 502  [-2.4709362920185014, 1.0725943178557489, 0.12...       0.183988
# 503  [-0.7257791024569386, -2.5495286830965465, 0.7...       0.355195
# 504  [2.6984126958655046, 0.017593618431285308, -0....       0.288293
# 505  [0.009821433074351807, 2.78491078237127, -0.11...       0.302418
# 506  [-1.4748443418651374, 2.3106058857489153, -0.0...       0.443549
#
#                                                  Na_Nc  tddft_angle_errors  \
# 0    [-0.29400000000000004, 4.065999999999999, -0.3...            6.754632
# 1    [3.653000000000006, 1.8580000000000005, -0.551...            7.226140
# 2    [-1.131999999999998, -3.8919999999999995, -0.3...            4.212450
# 3    [1.036999999999999, 4.018999999999998, -0.1140...            3.692699
# 4    [1.5859999999999985, -3.777000000000001, -0.36...            2.769908
# ..                                                 ...                 ...
# 502  [-3.908999999999999, 1.4699999999999989, -0.50...            6.162496
# 503  [0.2789999999999999, 4.154999999999994, -1.012...            5.319576
# 504  [-4.051, -0.08500000000000085, 0.4269999999999...            2.004818
# 505  [-0.1549999999999998, -4.112, -0.4310000000000...            2.933543
# 506  [-2.2300000000000004, 3.354, -0.7340000000000018]            0.830183
#
#      xtb_angle_errors
# 0            3.919135
# 1            8.515070
# 2           10.447244
# 3            6.957156
# 4            6.545793
# ..                ...
# 502          9.922109
# 503         11.893541
# 504          5.246490
# 505          8.616865
# 506         10.058324
#
# [507 rows x 12 columns]

# %%
previous_method = pd.read_pickle("gfn1/gfn1_eigdiff_test_no_RMSE.pkl")
previous_method
# Out:
#                  chromophores   set  tddft_energy  xtb_energy  energy_error  \
# 0     step_1001_chromophore_1  test      1.912907    2.679531      0.766624
# 1    step_1001_chromophore_12  test      1.800987    2.574462      0.773475
# 2    step_1001_chromophore_13  test      1.945561    2.721084      0.775524
# 3    step_1001_chromophore_15  test      1.872008    2.689341      0.817332
# 4    step_1001_chromophore_16  test      1.826320    2.615781      0.789460
# ..                        ...   ...           ...         ...           ...
# 502   step_951_chromophore_21  test      1.853668    2.642074      0.788406
# 503   step_951_chromophore_23  test      1.826429    2.623443      0.797014
# 504   step_951_chromophore_24  test      1.843708    2.597174      0.753465
# 505    step_951_chromophore_3  test      1.857586    2.646128      0.788542
# 506    step_951_chromophore_4  test      1.815708    2.550230      0.734522
#
#      Z_values                               tddft_dipoles  \
# 0   -0.382984    [-0.34950403, 2.653887491, -0.477898847]
# 1   -0.112651   [-2.287369813, -1.499455904, 0.193644764]
# 2   -0.031818   [-0.754756204, -2.53537159, -0.019176462]
# 3    1.617958   [-0.54968506, -2.608078035, -0.050338471]
# 4    0.518131    [-0.947789088, 2.495867441, 0.332799887]
# ..        ...                                         ...
# 502  0.476516   [-2.490853557, 1.063950918, -0.062505406]
# 503  0.816194   [-0.422365249, -2.610028365, 0.590992657]
# 504 -0.902238    [-2.783375996, 0.034964353, 0.263783579]
# 505  0.481879  [-0.012588919, -2.812019863, -0.183832072]
# 506 -1.649734     [1.46951434, -2.245793022, 0.454362367]
#
#                                            xtb_dipoles  dipole_errors  \
# 0    [-0.5260128223685893, 4.141766410711858, -0.35...       1.502977
# 1    [3.567871769700485, 2.2813695959737474, 0.1032...       1.529447
# 2    [1.257134669961684, 3.813206156349945, -0.9120...       1.659048
# 3    [-0.7762433183410005, -4.110894586034731, -0.4...       1.567526
# 4    [-1.540267497170829, 4.021675856670784, -0.112...       1.696354
# ..                                                 ...            ...
# 502  [-3.774098225222305, 1.6598669036516456, 0.553...       1.542949
# 503  [-1.3065814296652722, -3.8688977233552664, 1.3...       1.699127
# 504  [-4.179940413658589, -0.03521726823758756, 0.8...       1.534222
# 505  [-0.00975721339059315, 4.323559992879986, -0.5...       1.663290
# 506  [2.31556356458037, -3.6090001865079784, 0.0217...       1.661713
#
#                                                  Na_Nc  tddft_angle_errors  \
# 0    [-0.29400000000000004, 4.065999999999999, -0.3...            6.754632
# 1    [3.653000000000006, 1.8580000000000005, -0.551...            7.226140
# 2    [-1.131999999999998, -3.8919999999999995, -0.3...            4.212450
# 3    [1.036999999999999, 4.018999999999998, -0.1140...            3.692699
# 4    [1.5859999999999985, -3.777000000000001, -0.36...            2.769908
# ..                                                 ...                 ...
# 502  [-3.908999999999999, 1.4699999999999989, -0.50...            6.162496
# 503  [0.2789999999999999, 4.154999999999994, -1.012...            5.319576
# 504  [-4.051, -0.08500000000000085, 0.4269999999999...            2.004818
# 505  [-0.1549999999999998, -4.112, -0.4310000000000...            2.933543
# 506  [-2.2300000000000004, 3.354, -0.7340000000000018]            0.830183
#
#      xtb_angle_errors
# 0            3.164379
# 1           10.668910
# 2           17.526664
# 3            8.392888
# 4            6.904572
# ..                ...
# 502         14.918732
# 503         14.846547
# 504          6.111630
# 505         12.909194
# 506         10.080536
#
# [507 rows x 12 columns]

# %%
fig, ax = plt.subplots(1, 2) 

l1 = ax[0].scatter(dipole_results["tddft_energy"].to_numpy(), dipole_results["xtb_energy"].to_numpy(), color='red', marker='x')
l2 = ax[0].scatter(previous_method["tddft_energy"].to_numpy(), previous_method["xtb_energy"].to_numpy(), color='black', marker='x')
l5 = ax[0].plot(dipole_results["tddft_energy"].to_numpy(), dipole_results["tddft_energy"].to_numpy(), linestyle='--', color='grey')

l3 = ax[1].scatter([np.linalg.norm(x) for x in dipole_results["tddft_dipoles"]], [np.linalg.norm(x) for x in dipole_results["xtb_dipoles"]], color='red', marker='x')
l4 = ax[1].scatter([np.linalg.norm(x) for x in previous_method["tddft_dipoles"]], [np.linalg.norm(x) for x in previous_method["xtb_dipoles"]], color='black', marker='x')
ax[1].plot([np.linalg.norm(x) for x in previous_method["tddft_dipoles"]], [np.linalg.norm(x) for x in previous_method["tddft_dipoles"]], linestyle='--', color='grey')

ax[0].set_xlabel("TD-DFT")
ax[0].set_ylabel("xTB methods")

ax[1].set_xlabel("TD-DFT")
ax[1].set_ylabel("xTB methods")

ax[0].set_title("Excitation energy / eV")
ax[1].set_title("Transition dipole magnitude / au")

fig.legend((l1, l2, l5), ("Density Matrix scaling", "No scaling", "y=x"), 'center right')

fig.set_size_inches(24,12)
# Out:
# /Users/of15641/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x11669aa50>] instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
