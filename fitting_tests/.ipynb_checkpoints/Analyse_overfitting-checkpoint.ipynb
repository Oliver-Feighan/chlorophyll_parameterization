# %%
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import os
import re
import ast

# %% [markdown]
# ## Errors and correlations

# %%
directories = os.walk(".")
dirs = [i[0] for i in directories]
#dirs = [x for x in dirs if re.match(r'^.\/[a-z]+', x)]
dirs
# Out:
# ['.',
#  './huckel_electronegativity_global_pair_response',
#  './huckel_electronegativity_global_pair_response/.ipynb_checkpoints',
#  './huckel_electronegativity_response',
#  './huckel_electronegativity_kinetic_response',
#  './response',
#  './huckel_kinetic',
#  './global_pair_response',
#  './huckel_global_pair',
#  './kinetic_global_pair',
#  './huckel_global_pair_response',
#  './electronegativity_global_pair_response',
#  './huckel',
#  './electronegativity_global_pair',
#  './huckel_electronegativity_kinetic',
#  './electronegativity_kinetic_global_pair_response',
#  './huckel_electronegativity_kinetic_global_pair_response',
#  './global_pair',
#  './kinetic_response',
#  './huckel_kinetic_global_pair_response',
#  './huckel_electronegativity_global_pair',
#  './kinetic',
#  './.ipynb_checkpoints',
#  './huckel_kinetic_global_pair',
#  './huckel_electronegativity',
#  './huckel_global_pair_response_ao_energy_levels',
#  './huckel_kinetic_response',
#  './huckel_electronegativity_kinetic_global_pair',
#  './electronegativity_kinetic_response',
#  './electronegativity_kinetic_global_pair',
#  './huckel_response',
#  './kinetic_global_pair_response',
#  './electronegativity',
#  './electronegativity_response',
#  './electronegativity_kinetic']

# %%
directories = os.walk(".")

files = [i[2] for i in directories]

rerun_pile = []
output_files = []
test_result_files = []


for enum, f in enumerate(files):
    output_file = []
    
    if re.search(r'^./[a-z]+', dirs[enum]) is None:
        continue

    output_file = [x for x in f if re.search(r'[a-z]\.o\d+', x) is not None]
    df_file = [x for x in f if re.search(r'test_set_results.pkl', x) is not None]
    
    if len(df_file) == 0 or len(output_file) == 0:
        print(f"no test results file for {dirs[enum]}")
        rerun_pile.append(dirs[enum])
        continue
        
    output_files.append(dirs[enum] +"/" + output_file[0])
    test_result_files.append(df_file[0])
# Out:
# no test results file for ./huckel_electronegativity_global_pair_response/.ipynb_checkpoints
# no test results file for ./huckel_global_pair_response_ao_energy_levels

# %%
training = { 
    "no_params" : [],
    "RMSE_energies" : [],
    "R2_energies" : [],
    "R2_dipoles" : []
}

testing = { 
    "no_params" : [],
    "RMSE_energies" : [],
    "R2_energies" : [],
    "R2_dipoles" : []
}

overfitting_results = {}

for file in output_files:
    print(file)
    lines = list(open(file).readlines())
    
    parameters = [x for x in lines if "optimized parameters:" in x]
    
    if len(parameters) == 0:
        continue
    
    parameters = parameters[0]
    parameters = parameters.replace("optimized parameters:  ", "")
    parameters = parameters.replace("\n", "")
    parameters = ast.literal_eval(parameters)
    #print(parameters)
    
    training["no_params"].append(len(list(parameters.keys())))
    testing["no_params"].append(len(list(parameters.keys())))
    
    training_set_results = lines[-9]
    test_set_results = lines[-6]
    
    #print(training_set_results, end="")
    #print(test_set_results, end="")
    
    training_set_values = re.findall(r'-?\d+.\d+', training_set_results)
    test_set_values = re.findall(r'-?\d+.\d+', test_set_results)
    
    #print(training_set_values)
    #print(test_set_values)
    
    training["RMSE_energies"].append(float(training_set_values[0]))
    training["R2_energies"].append(float(training_set_values[1]))
    training["R2_dipoles"].append(float(training_set_values[2]))
    
    testing["RMSE_energies"].append(float(test_set_values[0]))
    testing["R2_energies"].append(float(test_set_values[1]))
    testing["R2_dipoles"].append(float(test_set_values[2]))
        
    overfitting_results[file.split("/")[1]] = {
        "no. params" : len(list(parameters.keys())),
        "parameters" : list(parameters.keys()),
        "RMSE energy (training)" : float(training_set_values[0]),
        "R2 energy (training)" : float(training_set_values[1]),
        "R2 dipole (training)" : float(training_set_values[2]),
        "obj. func. (training)" : float(training_set_values[0]) + (1-float(training_set_values[1])) + (1-float(training_set_values[2])),
        "RMSE energy (testing)" : float(test_set_values[0]),
        "R2 energy (testing)" : float(test_set_values[1]),
        "R2 dipole (testing)" : float(test_set_values[2]),
        "obj. func. (testing)" : float(test_set_values[0]) + (1-float(test_set_values[1])) + (1-float(test_set_values[2]))
    }
    
overfitting_df = pd.DataFrame.from_dict(overfitting_results, orient='index')
overfitting_df = overfitting_df.sort_values("R2 energy (testing)", ascending=False)
#overfitting_df = overfitting_df.sort_values("R2 dipole (testing)", ascending=False)

overfitting_df
# Out:
# ./huckel_electronegativity_global_pair_response/huckel_electronegativity_global_pair_response.o1404190
# ./huckel_electronegativity_response/huckel_electronegativity_response.o1404195
# ./huckel_electronegativity_kinetic_response/huckel_electronegativity_kinetic_response.o1404194
# ./response/response.o1404207
# ./huckel_kinetic/huckel_kinetic.o1404198
# ./global_pair_response/global_pair_response.o1404186
# ./huckel_global_pair/huckel_global_pair.o1404196
# ./kinetic_global_pair/kinetic_global_pair.o1404204
# ./huckel_global_pair_response/huckel_global_pair_response.o1404197
# ./electronegativity_global_pair_response/electronegativity_global_pair_response.o1404179
# ./huckel/huckel.o1476559
# ./electronegativity_global_pair/electronegativity_global_pair.o1404178
# ./huckel_electronegativity_kinetic/huckel_electronegativity_kinetic.o1404191
# ./electronegativity_kinetic_global_pair_response/electronegativity_kinetic_global_pair_response.o1404182
# ./huckel_electronegativity_kinetic_global_pair_response/huckel_electronegativity_kinetic_global_pair_response.o1404193
# ./global_pair/global_pair.o1404185
# ./kinetic_response/kinetic_response.o1404206
# ./huckel_kinetic_global_pair_response/huckel_kinetic_global_pair_response.o1404200
# ./huckel_electronegativity_global_pair/huckel_electronegativity_global_pair.o1404189
# ./kinetic/kinetic.o1404203
# ./huckel_kinetic_global_pair/huckel_kinetic_global_pair.o1404199
# ./huckel_electronegativity/huckel_electronegativity.o1404188
# ./huckel_kinetic_response/huckel_kinetic_response.o1404201
# ./huckel_electronegativity_kinetic_global_pair/huckel_electronegativity_kinetic_global_pair.o1404192
# ./electronegativity_kinetic_response/electronegativity_kinetic_response.o1404183
# ./electronegativity_kinetic_global_pair/electronegativity_kinetic_global_pair.o1404181
# ./huckel_response/huckel_response.o1404202
# ./kinetic_global_pair_response/kinetic_global_pair_response.o1404205
# ./electronegativity/electronegativity.o1404177
# ./electronegativity_response/electronegativity_response.o1404184
# ./electronegativity_kinetic/electronegativity_kinetic.o1404180
#                                                     no. params  \
# huckel_response                                              6
# huckel_global_pair_response                                 11
# huckel_kinetic_global_pair_response                         12
# electronegativity_kinetic_response                           7
# huckel_electronegativity_response                            9
# huckel_electronegativity_kinetic_response                   10
# kinetic_response                                             4
# huckel_electronegativity_kinetic_global_pair_re...          15
# huckel_kinetic_response                                      7
# huckel_electronegativity_global_pair_response               14
# response                                                     3
# electronegativity_response                                   6
# kinetic_global_pair_response                                 9
# electronegativity_global_pair_response                      11
# electronegativity_kinetic_global_pair_response              12
# huckel_global_pair                                           8
# huckel_electronegativity_global_pair                        11
# huckel_electronegativity_kinetic_global_pair                12
# huckel_electronegativity_kinetic                             7
# electronegativity_kinetic                                    4
# huckel_electronegativity                                     6
# electronegativity_kinetic_global_pair                        9
# electronegativity                                            3
# huckel_kinetic                                               4
# electronegativity_global_pair                                8
# global_pair_response                                         8
# kinetic_global_pair                                          6
# global_pair                                                  5
# huckel_kinetic_global_pair                                   9
# kinetic                                                      1
#
#                                                                                            parameters  \
# huckel_response                                                        [k_s, k_p, k_d, a_x, y_J, y_K]
# huckel_global_pair_response                         [k_s, k_p, k_d, Mg_s, Mg_p, Mg_d, N_s, N_p, a_...
# huckel_kinetic_global_pair_response                 [k_s, k_p, k_d, k_T, Mg_s, Mg_p, Mg_d, N_s, N_...
# electronegativity_kinetic_response                       [k_EN_s, k_EN_p, k_EN_d, k_T, a_x, y_J, y_K]
# huckel_electronegativity_response                   [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, a_x, y...
# huckel_electronegativity_kinetic_response           [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T, a...
# kinetic_response                                                                 [k_T, a_x, y_J, y_K]
# huckel_electronegativity_kinetic_global_pair_re...  [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T, M...
# huckel_kinetic_response                                           [k_s, k_p, k_d, k_T, a_x, y_J, y_K]
# huckel_electronegativity_global_pair_response       [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, Mg_s, ...
# response                                                                              [a_x, y_J, y_K]
# electronegativity_response                                    [k_EN_s, k_EN_p, k_EN_d, a_x, y_J, y_K]
# kinetic_global_pair_response                         [k_T, Mg_s, Mg_p, Mg_d, N_s, N_p, a_x, y_J, y_K]
# electronegativity_global_pair_response              [k_EN_s, k_EN_p, k_EN_d, Mg_s, Mg_p, Mg_d, N_s...
# electronegativity_kinetic_global_pair_response      [k_EN_s, k_EN_p, k_EN_d, k_T, Mg_s, Mg_p, Mg_d...
# huckel_global_pair                                        [k_s, k_p, k_d, Mg_s, Mg_p, Mg_d, N_s, N_p]
# huckel_electronegativity_global_pair                [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, Mg_s, ...
# huckel_electronegativity_kinetic_global_pair        [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T, M...
# huckel_electronegativity_kinetic                         [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T]
# electronegativity_kinetic                                               [k_EN_s, k_EN_p, k_EN_d, k_T]
# huckel_electronegativity                                      [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d]
# electronegativity_kinetic_global_pair               [k_EN_s, k_EN_p, k_EN_d, k_T, Mg_s, Mg_p, Mg_d...
# electronegativity                                                            [k_EN_s, k_EN_p, k_EN_d]
# huckel_kinetic                                                                   [k_s, k_p, k_d, k_T]
# electronegativity_global_pair                       [k_EN_s, k_EN_p, k_EN_d, Mg_s, Mg_p, Mg_d, N_s...
# global_pair_response                                      [Mg_s, Mg_p, Mg_d, N_s, N_p, a_x, y_J, y_K]
# kinetic_global_pair                                                 [k_T, Mg_s, Mg_p, Mg_d, N_s, N_p]
# global_pair                                                              [Mg_s, Mg_p, Mg_d, N_s, N_p]
# huckel_kinetic_global_pair                           [k_s, k_p, k_d, k_T, Mg_s, Mg_p, Mg_d, N_s, N_p]
# kinetic                                                                                         [k_T]
#
#                                                     RMSE energy (training)  \
# huckel_response                                                      0.020
# huckel_global_pair_response                                          0.020
# huckel_kinetic_global_pair_response                                  0.023
# electronegativity_kinetic_response                                   0.021
# huckel_electronegativity_response                                    0.020
# huckel_electronegativity_kinetic_response                            0.025
# kinetic_response                                                     0.027
# huckel_electronegativity_kinetic_global_pair_re...                   0.034
# huckel_kinetic_response                                              0.033
# huckel_electronegativity_global_pair_response                        0.035
# response                                                             0.026
# electronegativity_response                                           0.022
# kinetic_global_pair_response                                         0.039
# electronegativity_global_pair_response                               0.025
# electronegativity_kinetic_global_pair_response                       0.045
# huckel_global_pair                                                   0.085
# huckel_electronegativity_global_pair                                 0.085
# huckel_electronegativity_kinetic_global_pair                         0.079
# huckel_electronegativity_kinetic                                     0.083
# electronegativity_kinetic                                            0.081
# huckel_electronegativity                                             0.080
# electronegativity_kinetic_global_pair                                0.086
# electronegativity                                                    0.084
# huckel_kinetic                                                       0.098
# electronegativity_global_pair                                        0.078
# global_pair_response                                                 0.069
# kinetic_global_pair                                                  0.118
# global_pair                                                          0.118
# huckel_kinetic_global_pair                                           0.151
# kinetic                                                              0.186
#
#                                                     R2 energy (training)  \
# huckel_response                                                    0.725
# huckel_global_pair_response                                        0.726
# huckel_kinetic_global_pair_response                                0.748
# electronegativity_kinetic_response                                 0.684
# huckel_electronegativity_response                                  0.721
# huckel_electronegativity_kinetic_response                          0.690
# kinetic_response                                                   0.601
# huckel_electronegativity_kinetic_global_pair_re...                 0.725
# huckel_kinetic_response                                            0.529
# huckel_electronegativity_global_pair_response                      0.718
# response                                                           0.515
# electronegativity_response                                         0.618
# kinetic_global_pair_response                                       0.563
# electronegativity_global_pair_response                             0.582
# electronegativity_kinetic_global_pair_response                     0.510
# huckel_global_pair                                                 0.338
# huckel_electronegativity_global_pair                               0.396
# huckel_electronegativity_kinetic_global_pair                       0.322
# huckel_electronegativity_kinetic                                   0.308
# electronegativity_kinetic                                          0.228
# huckel_electronegativity                                           0.327
# electronegativity_kinetic_global_pair                              0.263
# electronegativity                                                  0.169
# huckel_kinetic                                                     0.189
# electronegativity_global_pair                                      0.165
# global_pair_response                                               0.107
# kinetic_global_pair                                                0.126
# global_pair                                                        0.092
# huckel_kinetic_global_pair                                         0.027
# kinetic                                                            0.010
#
#                                                     R2 dipole (training)  \
# huckel_response                                                    0.141
# huckel_global_pair_response                                        0.188
# huckel_kinetic_global_pair_response                                0.172
# electronegativity_kinetic_response                                 0.210
# huckel_electronegativity_response                                  0.184
# huckel_electronegativity_kinetic_response                          0.185
# kinetic_response                                                   0.140
# huckel_electronegativity_kinetic_global_pair_re...                 0.194
# huckel_kinetic_response                                            0.180
# huckel_electronegativity_global_pair_response                      0.167
# response                                                           0.164
# electronegativity_response                                         0.137
# kinetic_global_pair_response                                       0.189
# electronegativity_global_pair_response                             0.259
# electronegativity_kinetic_global_pair_response                     0.181
# huckel_global_pair                                                 0.094
# huckel_electronegativity_global_pair                               0.133
# huckel_electronegativity_kinetic_global_pair                       0.191
# huckel_electronegativity_kinetic                                   0.190
# electronegativity_kinetic                                          0.179
# huckel_electronegativity                                           0.105
# electronegativity_kinetic_global_pair                              0.194
# electronegativity                                                  0.147
# huckel_kinetic                                                     0.186
# electronegativity_global_pair                                      0.161
# global_pair_response                                               0.186
# kinetic_global_pair                                                0.063
# global_pair                                                        0.152
# huckel_kinetic_global_pair                                         0.061
# kinetic                                                            0.181
#
#                                                     obj. func. (training)  \
# huckel_response                                                     1.154
# huckel_global_pair_response                                         1.106
# huckel_kinetic_global_pair_response                                 1.103
# electronegativity_kinetic_response                                  1.127
# huckel_electronegativity_response                                   1.115
# huckel_electronegativity_kinetic_response                           1.150
# kinetic_response                                                    1.286
# huckel_electronegativity_kinetic_global_pair_re...                  1.115
# huckel_kinetic_response                                             1.324
# huckel_electronegativity_global_pair_response                       1.150
# response                                                            1.347
# electronegativity_response                                          1.267
# kinetic_global_pair_response                                        1.287
# electronegativity_global_pair_response                              1.184
# electronegativity_kinetic_global_pair_response                      1.354
# huckel_global_pair                                                  1.653
# huckel_electronegativity_global_pair                                1.556
# huckel_electronegativity_kinetic_global_pair                        1.566
# huckel_electronegativity_kinetic                                    1.585
# electronegativity_kinetic                                           1.674
# huckel_electronegativity                                            1.648
# electronegativity_kinetic_global_pair                               1.629
# electronegativity                                                   1.768
# huckel_kinetic                                                      1.723
# electronegativity_global_pair                                       1.752
# global_pair_response                                                1.776
# kinetic_global_pair                                                 1.929
# global_pair                                                         1.874
# huckel_kinetic_global_pair                                          2.063
# kinetic                                                             1.995
#
#                                                     RMSE energy (testing)  \
# huckel_response                                                     0.021
# huckel_global_pair_response                                         0.022
# huckel_kinetic_global_pair_response                                 0.026
# electronegativity_kinetic_response                                  0.024
# huckel_electronegativity_response                                   0.024
# huckel_electronegativity_kinetic_response                           0.029
# kinetic_response                                                    0.026
# huckel_electronegativity_kinetic_global_pair_re...                  0.039
# huckel_kinetic_response                                             0.035
# huckel_electronegativity_global_pair_response                       0.044
# response                                                            0.027
# electronegativity_response                                          0.026
# kinetic_global_pair_response                                        0.040
# electronegativity_global_pair_response                              0.032
# electronegativity_kinetic_global_pair_response                      0.048
# huckel_global_pair                                                  0.100
# huckel_electronegativity_global_pair                                0.107
# huckel_electronegativity_kinetic_global_pair                        0.105
# huckel_electronegativity_kinetic                                    0.102
# electronegativity_kinetic                                           0.084
# huckel_electronegativity                                            0.096
# electronegativity_kinetic_global_pair                               0.108
# electronegativity                                                   0.089
# huckel_kinetic                                                      0.107
# electronegativity_global_pair                                       0.104
# global_pair_response                                                0.081
# kinetic_global_pair                                                 0.140
# global_pair                                                         0.142
# huckel_kinetic_global_pair                                          0.151
# kinetic                                                             0.178
#
#                                                     R2 energy (testing)  \
# huckel_response                                                   0.699
# huckel_global_pair_response                                       0.696
# huckel_kinetic_global_pair_response                               0.672
# electronegativity_kinetic_response                                0.652
# huckel_electronegativity_response                                 0.646
# huckel_electronegativity_kinetic_response                         0.618
# kinetic_response                                                  0.609
# huckel_electronegativity_kinetic_global_pair_re...                0.592
# huckel_kinetic_response                                           0.489
# huckel_electronegativity_global_pair_response                     0.489
# response                                                          0.489
# electronegativity_response                                        0.488
# kinetic_global_pair_response                                      0.471
# electronegativity_global_pair_response                            0.415
# electronegativity_kinetic_global_pair_response                    0.345
# huckel_global_pair                                                0.257
# huckel_electronegativity_global_pair                              0.242
# huckel_electronegativity_kinetic_global_pair                      0.218
# huckel_electronegativity_kinetic                                  0.211
# electronegativity_kinetic                                         0.205
# huckel_electronegativity                                          0.188
# electronegativity_kinetic_global_pair                             0.184
# electronegativity                                                 0.158
# huckel_kinetic                                                    0.134
# electronegativity_global_pair                                     0.121
# global_pair_response                                              0.118
# kinetic_global_pair                                               0.109
# global_pair                                                       0.106
# huckel_kinetic_global_pair                                        0.057
# kinetic                                                           0.037
#
#                                                     R2 dipole (testing)  \
# huckel_response                                                   0.184
# huckel_global_pair_response                                       0.193
# huckel_kinetic_global_pair_response                               0.169
# electronegativity_kinetic_response                                0.187
# huckel_electronegativity_response                                 0.188
# huckel_electronegativity_kinetic_response                         0.202
# kinetic_response                                                  0.161
# huckel_electronegativity_kinetic_global_pair_re...                0.189
# huckel_kinetic_response                                           0.176
# huckel_electronegativity_global_pair_response                     0.157
# response                                                          0.200
# electronegativity_response                                        0.179
# kinetic_global_pair_response                                      0.197
# electronegativity_global_pair_response                            0.200
# electronegativity_kinetic_global_pair_response                    0.175
# huckel_global_pair                                                0.150
# huckel_electronegativity_global_pair                              0.182
# huckel_electronegativity_kinetic_global_pair                      0.183
# huckel_electronegativity_kinetic                                  0.190
# electronegativity_kinetic                                         0.167
# huckel_electronegativity                                          0.149
# electronegativity_kinetic_global_pair                             0.183
# electronegativity                                                 0.176
# huckel_kinetic                                                    0.223
# electronegativity_global_pair                                     0.198
# global_pair_response                                              0.210
# kinetic_global_pair                                               0.112
# global_pair                                                       0.212
# huckel_kinetic_global_pair                                        0.035
# kinetic                                                           0.192
#
#                                                     obj. func. (testing)
# huckel_response                                                    1.138
# huckel_global_pair_response                                        1.133
# huckel_kinetic_global_pair_response                                1.185
# electronegativity_kinetic_response                                 1.185
# huckel_electronegativity_response                                  1.190
# huckel_electronegativity_kinetic_response                          1.209
# kinetic_response                                                   1.256
# huckel_electronegativity_kinetic_global_pair_re...                 1.258
# huckel_kinetic_response                                            1.370
# huckel_electronegativity_global_pair_response                      1.398
# response                                                           1.338
# electronegativity_response                                         1.359
# kinetic_global_pair_response                                       1.372
# electronegativity_global_pair_response                             1.417
# electronegativity_kinetic_global_pair_response                     1.528
# huckel_global_pair                                                 1.693
# huckel_electronegativity_global_pair                               1.683
# huckel_electronegativity_kinetic_global_pair                       1.704
# huckel_electronegativity_kinetic                                   1.701
# electronegativity_kinetic                                          1.712
# huckel_electronegativity                                           1.759
# electronegativity_kinetic_global_pair                              1.741
# electronegativity                                                  1.755
# huckel_kinetic                                                     1.750
# electronegativity_global_pair                                      1.785
# global_pair_response                                               1.753
# kinetic_global_pair                                                1.919
# global_pair                                                        1.824
# huckel_kinetic_global_pair                                         2.059
# kinetic                                                            1.949

# %%
fig, ax = plt.subplots()

training_objective_function = np.array(training["RMSE_energies"]) + (1-np.array(training["R2_energies"])) + (1-np.array(training["R2_dipoles"]))
testing_objective_function = np.array(testing["RMSE_energies"]) + (1-np.array(testing["R2_energies"])) + (1-np.array(testing["R2_dipoles"]))

ax.scatter(training["no_params"], training_objective_function, color='red', label="training set")
ax.scatter(testing["no_params"], testing_objective_function, color='black', label="testing set")

ax.set_xlabel("# of parameters")
ax.set_ylabel("Objective function")
ax.set_title("overfitting plot for full objective function")
ax.legend()
fig.set_size_inches(12,12)

# %%
fig, ax = plt.subplots()

ax.scatter(training["no_params"], training["RMSE_energies"], color='red')
ax.scatter(testing["no_params"], testing["RMSE_energies"], color='black')

ax.set_xlabel("# of parameters")
ax.set_ylabel("RMSE of excitation energy / eV")
ax.set_title("overfitting plot for excitation energy RMSE")
fig.set_size_inches(12,12)

# %%
fig, ax = plt.subplots()

ax.scatter(training["no_params"], training["R2_energies"], color='red')
ax.scatter(testing["no_params"], testing["R2_energies"], color='black')

ax.set_xlabel("# of parameters")
ax.set_ylabel("R^2 for excitation energy")
ax.set_title("overfitting plot for excitation energy correlation")

fig.set_size_inches(12,12)

# %%
fig, ax = plt.subplots()

ax.scatter(training["no_params"], training["R2_dipoles"], color='red')
ax.scatter(testing["no_params"], testing["R2_dipoles"], color='black')

ax.set_xlabel("# of parameters")
ax.set_ylabel("R^2 for transition dipole magnitude")
ax.set_title("overfitting plot for transition dipole magnitude correlation")

fig.set_size_inches(12,12)

# %%
def get_df(file_name):
    df = pkl.load(open(f"{file_name}/test_set_results.pkl", 'rb'))
    
    return df

huckel_global_pair_response_df = get_df("huckel_global_pair_response")

# %%
huckel_global_pair_response_df.corr()
# Out:
#                     tddft_energy  xtb_energy  energy_error  Z_values  \
# tddft_energy            1.000000    0.779657     -0.111547 -0.111547
# xtb_energy              0.779657    1.000000      0.535331  0.535331
# energy_error           -0.111547    0.535331      1.000000  1.000000
# Z_values               -0.111547    0.535331      1.000000  1.000000
# dipole_errors           0.031790    0.100789      0.117068  0.117068
# tddft_angle_errors     -0.052288   -0.035761      0.013776  0.013776
# xtb_angle_errors       -0.175803   -0.056269      0.147832  0.147832
#
#                     dipole_errors  tddft_angle_errors  xtb_angle_errors
# tddft_energy             0.031790           -0.052288         -0.175803
# xtb_energy               0.100789           -0.035761         -0.056269
# energy_error             0.117068            0.013776          0.147832
# Z_values                 0.117068            0.013776          0.147832
# dipole_errors            1.000000           -0.078642         -0.124473
# tddft_angle_errors      -0.078642            1.000000          0.449336
# xtb_angle_errors        -0.124473            0.449336          1.000000

# %%
def energy_scatter(df):
    test_rows = df.loc[df["set"] == "test"]
    training_rows = df.loc[df["set"] == "training"]

    fig, ax = plt.subplots()

    test_rows.plot.scatter("tddft_energy", "xtb_energy", marker='x', color='black', ax=ax)
    training_rows.plot.scatter("tddft_energy", "xtb_energy", marker='x', color='red', ax=ax)
    
    fig.set_size_inches(12, 12)
    
    xmin, xmax = ax.get_xlim()
    ymin, ymax = ax.get_ylim()
    
    ax.plot([xmin, xmax], [ymin, ymax], color='black', linestyle='--')
    
    plt.show()
    
energy_scatter(huckel_global_pair_response_df)

# %%
def angles_scatter(df):
    test_df = df.loc[df["set"] == "test"]
    training_df = df.loc[df["set"] == "training"]
    
    fig, ax = plt.subplots()
    
    test_df.plot.scatter("tddft_angle_errors", "xtb_angle_errors", marker='x', color='black', ax=ax)
    training_df.plot.scatter("tddft_angle_errors", "xtb_angle_errors", marker='x', color='red', ax=ax)
    
    fig.set_size_inches(12, 12)
    
    xmin, xmax = ax.get_xlim()
    ymin, ymax = ax.get_ylim()
    
    ax.plot([xmin, xmax], [ymin, ymax], color='black', linestyle='--')
    
    plt.show()

    
angles_scatter(huckel_global_pair_response_df)

# %%
def mag(vec):
    return np.linalg.norm(np.array(vec))

def mags_scatter(df):
    training_df = df.loc[df["set"] == "training"]
    test_df = df.loc[df["set"] == "test"]
    
    train_xtb_mags = []
    train_tddft_mags = []

    test_xtb_mags = []
    test_tddft_mags = []
    
    for index, row in training_df.iterrows():
        train_xtb_mags.append(mag(row["xtb_dipoles"]))
        train_tddft_mags.append(mag(row["tddft_dipoles"]))
    
    for index, row in test_df.iterrows():
        test_xtb_mags.append(mag(row["xtb_dipoles"]))
        test_tddft_mags.append(mag(row["tddft_dipoles"]))
        
    fig, ax = plt.subplots()

    from scipy.stats import linregress
    slope, intercept, r_value, _, _ = linregress(test_tddft_mags, test_xtb_mags)
    print("slope", slope)
    print("intercept", intercept)
    print("r^2", r_value**2)
    
    ax.scatter(train_tddft_mags, train_xtb_mags, color='red', marker='x')
    ax.scatter(test_tddft_mags, test_xtb_mags, color='black', marker='x')
    
    
    fig.set_size_inches(12, 12)
    
    xmin, xmax = ax.get_xlim()
    
    x_values = np.linspace(xmin, xmax, 100)
    best_fit = lambda x : intercept + slope * x
    ax.plot(x_values, best_fit(x_values), linestyle="--", color='black')
    
    
    ymin, ymax = ax.get_ylim()
    
    #ax.plot([xmin, xmax], [ymin, ymax], color='black', linestyle='--')
    
    plt.show()

    
mags_scatter(huckel_global_pair_response_df)
# Out:
# slope 0.6799222158583093
# intercept 2.653656573581903
# r^2 0.18388391574746124

# %% [markdown]
# ## Weighting search

# %%
directories = os.walk(".")

files = [i[2] for i in directories]

just_dipole_outputs = []
just_dipole_test_results = []

for enum, f in enumerate(files):
    if re.search(r'^./[a-z]+', dirs[enum]) is None:
        continue
    
    name = dirs[enum][2:]
    output_file = [x for x in f if re.search(fr'{name}.*.out', x) is not None]
    output_file = [x for x in output_file if re.search(r'.*a_0.0_b_0.0_c_1.0.*', x) is not None]
    
    df_file = [x for x in f if re.search(fr'{name}.*.pkl', x) is not None]
    df_file = [x for x in df_file if re.search(r'.*a_0.0_b_0.0_c_1.0.*', x) is not None]

    just_dipole_outputs.append(dirs[enum] +"/" + output_file[0])
    just_dipole_test_results.append(df_file[0])
    
print(just_dipole_outputs)
# Out:
# ['./huckel_electronegativity_global_pair_response/huckel_electronegativity_global_pair_response_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity_response/huckel_electronegativity_response_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity_kinetic_response/huckel_electronegativity_kinetic_response_a_0.0_b_0.0_c_1.0.out', './response/response_a_0.0_b_0.0_c_1.0.out', './huckel_kinetic/huckel_kinetic_a_0.0_b_0.0_c_1.0.out', './global_pair_response/global_pair_response_a_0.0_b_0.0_c_1.0.out', './huckel_global_pair/huckel_global_pair_a_0.0_b_0.0_c_1.0.out', './kinetic_global_pair/kinetic_global_pair_a_0.0_b_0.0_c_1.0.out', './huckel_global_pair_response/huckel_global_pair_response_a_0.0_b_0.0_c_1.0.out', './electronegativity_global_pair_response/electronegativity_global_pair_response_a_0.0_b_0.0_c_1.0.out', './huckel/huckel_a_0.0_b_0.0_c_1.0.out', './electronegativity_global_pair/electronegativity_global_pair_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity_kinetic/huckel_electronegativity_kinetic_a_0.0_b_0.0_c_1.0.out', './electronegativity_kinetic_global_pair_response/electronegativity_kinetic_global_pair_response_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity_kinetic_global_pair_response/huckel_electronegativity_kinetic_global_pair_response_a_0.0_b_0.0_c_1.0.out', './global_pair/global_pair_a_0.0_b_0.0_c_1.0.out', './kinetic_response/kinetic_response_a_0.0_b_0.0_c_1.0.out', './huckel_kinetic_global_pair_response/huckel_kinetic_global_pair_response_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity_global_pair/huckel_electronegativity_global_pair_a_0.0_b_0.0_c_1.0.out', './kinetic/kinetic_a_0.0_b_0.0_c_1.0.out', './huckel_kinetic_global_pair/huckel_kinetic_global_pair_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity/huckel_electronegativity_a_0.0_b_0.0_c_1.0.out', './huckel_kinetic_response/huckel_kinetic_response_a_0.0_b_0.0_c_1.0.out', './huckel_electronegativity_kinetic_global_pair/huckel_electronegativity_kinetic_global_pair_a_0.0_b_0.0_c_1.0.out', './electronegativity_kinetic_response/electronegativity_kinetic_response_a_0.0_b_0.0_c_1.0.out', './electronegativity_kinetic_global_pair/electronegativity_kinetic_global_pair_a_0.0_b_0.0_c_1.0.out', './huckel_response/huckel_response_a_0.0_b_0.0_c_1.0.out', './kinetic_global_pair_response/kinetic_global_pair_response_a_0.0_b_0.0_c_1.0.out', './electronegativity/electronegativity_a_0.0_b_0.0_c_1.0.out', './electronegativity_response/electronegativity_response_a_0.0_b_0.0_c_1.0.out', './electronegativity_kinetic/electronegativity_kinetic_a_0.0_b_0.0_c_1.0.out']

# %%
training = { 
    "no_params" : [],
    "RMSE_energies" : [],
    "R2_energies" : [],
    "R2_dipoles" : [],
    "obj. func." : []
}

testing = { 
    "no_params" : [],
    "RMSE_energies" : [],
    "R2_energies" : [],
    "R2_dipoles" : [],
    "obj. func." : []
}

overfitting_results = {}

for file in just_dipole_outputs:
    lines = list(open(file).readlines())
    
    parameters = [x for x in lines if "optimized parameters:" in x]
    parameters = parameters[0]
    parameters = parameters.replace("optimized parameters: ", "")
    parameters = parameters.replace("\n", "")
    parameters = ast.literal_eval(parameters)

    training["no_params"].append(len(list(parameters.keys())))
    testing["no_params"].append(len(list(parameters.keys())))
    
    training_set_results = lines[-10]
    test_set_results = lines[-7]
    
    #print(training_set_results, end="")
    #print(test_set_results, end="")
    
    training_set_values = re.findall(r'-?\d+.\d+', training_set_results)
    test_set_values = re.findall(r'-?\d+.\d+', test_set_results)
    
    #print(training_set_values)
    #print(test_set_values)
    
    training["RMSE_energies"].append(float(training_set_values[0]))
    training["R2_energies"].append(float(training_set_values[1]))
    training["R2_dipoles"].append(float(training_set_values[2]))
    training["obj. func."].append(float(training_set_values[3]))
    
    testing["RMSE_energies"].append(float(test_set_values[0]))
    testing["R2_energies"].append(float(test_set_values[1]))
    testing["R2_dipoles"].append(float(test_set_values[2]))
    testing["obj. func."].append(float(test_set_values[3]))
        
    overfitting_results[file.split("/")[1]] = {
        "no. params" : len(list(parameters.keys())),
        "parameters" : list(parameters.keys()),
        "RMSE energy (training)" : float(training_set_values[0]),
        "R2 energy (training)" : float(training_set_values[1]),
        "R2 dipole (training)" : float(training_set_values[2]),
        "obj. func. (training)" : float(training_set_values[3]),
        "RMSE energy (testing)" : float(test_set_values[0]),
        "R2 energy (testing)" : float(test_set_values[1]),
        "R2 dipole (testing)" : float(test_set_values[2]),
        "obj. func. (testing)" : float(test_set_values[3])
    }
    
overfitting_df = pd.DataFrame.from_dict(overfitting_results, orient='index')
#overfitting_df = overfitting_df.sort_values("R2 energy (testing)", ascending=False)
overfitting_df = overfitting_df.sort_values("R2 dipole (testing)", ascending=False)

overfitting_df
# Out:
#                                                     no. params  \
# huckel_global_pair                                           8
# huckel_electronegativity_kinetic_global_pair                12
# huckel_electronegativity_kinetic_global_pair_re...          15
# huckel_electronegativity_global_pair                        11
# global_pair                                                  5
# kinetic                                                      1
# kinetic_response                                             4
# response                                                     3
# electronegativity_global_pair                                8
# electronegativity_response                                   6
# electronegativity                                            3
# global_pair_response                                         8
# huckel                                                       3
# huckel_response                                              6
# huckel_electronegativity                                     6
# huckel_electronegativity_response                            9
# huckel_kinetic_global_pair                                   9
# huckel_electronegativity_kinetic_response                   10
# huckel_kinetic                                               4
# electronegativity_kinetic_response                           7
# electronegativity_global_pair_response                      11
# kinetic_global_pair                                          6
# huckel_global_pair_response                                 11
# huckel_kinetic_global_pair_response                         12
# electronegativity_kinetic_global_pair                        9
# huckel_kinetic_response                                      7
# electronegativity_kinetic                                    4
# electronegativity_kinetic_global_pair_response              12
# huckel_electronegativity_kinetic                             7
# huckel_electronegativity_global_pair_response               14
# kinetic_global_pair_response                                 9
#
#                                                                                            parameters  \
# huckel_global_pair                                        [k_s, k_p, k_d, Mg_s, Mg_p, Mg_d, N_s, N_p]
# huckel_electronegativity_kinetic_global_pair        [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T, M...
# huckel_electronegativity_kinetic_global_pair_re...  [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T, M...
# huckel_electronegativity_global_pair                [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, Mg_s, ...
# global_pair                                                              [Mg_s, Mg_p, Mg_d, N_s, N_p]
# kinetic                                                                                         [k_T]
# kinetic_response                                                                 [k_T, a_x, y_J, y_K]
# response                                                                              [a_x, y_J, y_K]
# electronegativity_global_pair                       [k_EN_s, k_EN_p, k_EN_d, Mg_s, Mg_p, Mg_d, N_s...
# electronegativity_response                                    [k_EN_s, k_EN_p, k_EN_d, a_x, y_J, y_K]
# electronegativity                                                            [k_EN_s, k_EN_p, k_EN_d]
# global_pair_response                                      [Mg_s, Mg_p, Mg_d, N_s, N_p, a_x, y_J, y_K]
# huckel                                                                                [k_s, k_p, k_d]
# huckel_response                                                        [k_s, k_p, k_d, a_x, y_J, y_K]
# huckel_electronegativity                                      [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d]
# huckel_electronegativity_response                   [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, a_x, y...
# huckel_kinetic_global_pair                           [k_s, k_p, k_d, k_T, Mg_s, Mg_p, Mg_d, N_s, N_p]
# huckel_electronegativity_kinetic_response           [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T, a...
# huckel_kinetic                                                                   [k_s, k_p, k_d, k_T]
# electronegativity_kinetic_response                       [k_EN_s, k_EN_p, k_EN_d, k_T, a_x, y_J, y_K]
# electronegativity_global_pair_response              [k_EN_s, k_EN_p, k_EN_d, Mg_s, Mg_p, Mg_d, N_s...
# kinetic_global_pair                                                 [k_T, Mg_s, Mg_p, Mg_d, N_s, N_p]
# huckel_global_pair_response                         [k_s, k_p, k_d, Mg_s, Mg_p, Mg_d, N_s, N_p, a_...
# huckel_kinetic_global_pair_response                 [k_s, k_p, k_d, k_T, Mg_s, Mg_p, Mg_d, N_s, N_...
# electronegativity_kinetic_global_pair               [k_EN_s, k_EN_p, k_EN_d, k_T, Mg_s, Mg_p, Mg_d...
# huckel_kinetic_response                                           [k_s, k_p, k_d, k_T, a_x, y_J, y_K]
# electronegativity_kinetic                                               [k_EN_s, k_EN_p, k_EN_d, k_T]
# electronegativity_kinetic_global_pair_response      [k_EN_s, k_EN_p, k_EN_d, k_T, Mg_s, Mg_p, Mg_d...
# huckel_electronegativity_kinetic                         [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, k_T]
# huckel_electronegativity_global_pair_response       [k_s, k_p, k_d, k_EN_s, k_EN_p, k_EN_d, Mg_s, ...
# kinetic_global_pair_response                         [k_T, Mg_s, Mg_p, Mg_d, N_s, N_p, a_x, y_J, y_K]
#
#                                                     RMSE energy (training)  \
# huckel_global_pair                                                   0.534
# huckel_electronegativity_kinetic_global_pair                         0.362
# huckel_electronegativity_kinetic_global_pair_re...                   0.444
# huckel_electronegativity_global_pair                                 3.665
# global_pair                                                          0.307
# kinetic                                                              1.179
# kinetic_response                                                     1.179
# response                                                             1.261
# electronegativity_global_pair                                        0.404
# electronegativity_response                                           2.244
# electronegativity                                                    2.647
# global_pair_response                                                 0.122
# huckel                                                               2.464
# huckel_response                                                      2.456
# huckel_electronegativity                                             3.489
# huckel_electronegativity_response                                    3.347
# huckel_kinetic_global_pair                                        2997.563
# huckel_electronegativity_kinetic_response                         2491.527
# huckel_kinetic                                                    1848.384
# electronegativity_kinetic_response                                3627.088
# electronegativity_global_pair_response                              20.245
# kinetic_global_pair                                               4133.015
# huckel_global_pair_response                                       1578.385
# huckel_kinetic_global_pair_response                               2477.996
# electronegativity_kinetic_global_pair                             2398.018
# huckel_kinetic_response                                            607.308
# electronegativity_kinetic                                           77.032
# electronegativity_kinetic_global_pair_response                    3323.762
# huckel_electronegativity_kinetic                                  2545.176
# huckel_electronegativity_global_pair_response                       37.737
# kinetic_global_pair_response                                      3490.098
#
#                                                     R2 energy (training)  \
# huckel_global_pair                                                 0.071
# huckel_electronegativity_kinetic_global_pair                       0.053
# huckel_electronegativity_kinetic_global_pair_re...                 0.022
# huckel_electronegativity_global_pair                               0.123
# global_pair                                                        0.125
# kinetic                                                            0.024
# kinetic_response                                                   0.024
# response                                                           0.022
# electronegativity_global_pair                                      0.077
# electronegativity_response                                         0.004
# electronegativity                                                  0.024
# global_pair_response                                               0.131
# huckel                                                             0.052
# huckel_response                                                    0.052
# huckel_electronegativity                                           0.009
# huckel_electronegativity_response                                  0.010
# huckel_kinetic_global_pair                                         0.063
# huckel_electronegativity_kinetic_response                          0.020
# huckel_kinetic                                                     0.001
# electronegativity_kinetic_response                                 0.015
# electronegativity_global_pair_response                             0.007
# kinetic_global_pair                                                0.025
# huckel_global_pair_response                                        0.053
# huckel_kinetic_global_pair_response                                0.048
# electronegativity_kinetic_global_pair                              0.019
# huckel_kinetic_response                                            0.016
# electronegativity_kinetic                                          0.003
# electronegativity_kinetic_global_pair_response                     0.042
# huckel_electronegativity_kinetic                                   0.016
# huckel_electronegativity_global_pair_response                      0.010
# kinetic_global_pair_response                                       0.043
#
#                                                     R2 dipole (training)  \
# huckel_global_pair                                                 0.292
# huckel_electronegativity_kinetic_global_pair                       0.231
# huckel_electronegativity_kinetic_global_pair_re...                 0.290
# huckel_electronegativity_global_pair                               0.309
# global_pair                                                        0.210
# kinetic                                                            0.195
# kinetic_response                                                   0.195
# response                                                           0.195
# electronegativity_global_pair                                      0.227
# electronegativity_response                                         0.207
# electronegativity                                                  0.210
# global_pair_response                                               0.192
# huckel                                                             0.235
# huckel_response                                                    0.235
# huckel_electronegativity                                           0.239
# huckel_electronegativity_response                                  0.239
# huckel_kinetic_global_pair                                         0.098
# huckel_electronegativity_kinetic_response                          0.090
# huckel_kinetic                                                     0.075
# electronegativity_kinetic_response                                 0.003
# electronegativity_global_pair_response                             0.115
# kinetic_global_pair                                                0.041
# huckel_global_pair_response                                        0.016
# huckel_kinetic_global_pair_response                                0.145
# electronegativity_kinetic_global_pair                              0.061
# huckel_kinetic_response                                            0.059
# electronegativity_kinetic                                          0.058
# electronegativity_kinetic_global_pair_response                     0.000
# huckel_electronegativity_kinetic                                   0.090
# huckel_electronegativity_global_pair_response                      0.029
# kinetic_global_pair_response                                       0.003
#
#                                                     obj. func. (training)  \
# huckel_global_pair                                               0.708326
# huckel_electronegativity_kinetic_global_pair                     0.768676
# huckel_electronegativity_kinetic_global_pair_re...               0.710265
# huckel_electronegativity_global_pair                             0.690860
# global_pair                                                      0.789918
# kinetic                                                          0.804570
# kinetic_response                                                 0.804570
# response                                                         0.805044
# electronegativity_global_pair                                    0.773073
# electronegativity_response                                       0.792740
# electronegativity                                                0.790433
# global_pair_response                                             0.807840
# huckel                                                           0.764759
# huckel_response                                                  0.764757
# huckel_electronegativity                                         0.761346
# huckel_electronegativity_response                                0.761355
# huckel_kinetic_global_pair                                       0.902353
# huckel_electronegativity_kinetic_response                        0.909791
# huckel_kinetic                                                   0.924715
# electronegativity_kinetic_response                               0.997413
# electronegativity_global_pair_response                           0.885035
# kinetic_global_pair                                              0.958745
# huckel_global_pair_response                                      0.983772
# huckel_kinetic_global_pair_response                              0.854916
# electronegativity_kinetic_global_pair                            0.938568
# huckel_kinetic_response                                          0.940531
# electronegativity_kinetic                                        0.941545
# electronegativity_kinetic_global_pair_response                   0.999960
# huckel_electronegativity_kinetic                                 0.910276
# huckel_electronegativity_global_pair_response                    0.970863
# kinetic_global_pair_response                                     0.996707
#
#                                                     RMSE energy (testing)  \
# huckel_global_pair                                                  0.577
# huckel_electronegativity_kinetic_global_pair                        0.362
# huckel_electronegativity_kinetic_global_pair_re...                  0.451
# huckel_electronegativity_global_pair                                3.686
# global_pair                                                         0.312
# kinetic                                                             1.170
# kinetic_response                                                    1.170
# response                                                            1.250
# electronegativity_global_pair                                       0.399
# electronegativity_response                                          2.233
# electronegativity                                                   2.637
# global_pair_response                                                0.127
# huckel                                                              2.440
# huckel_response                                                     2.432
# huckel_electronegativity                                            3.448
# huckel_electronegativity_response                                   3.307
# huckel_kinetic_global_pair                                       3011.496
# huckel_electronegativity_kinetic_response                        2484.501
# huckel_kinetic                                                   1846.614
# electronegativity_kinetic_response                               3641.326
# electronegativity_global_pair_response                             19.743
# kinetic_global_pair                                              4139.430
# huckel_global_pair_response                                      1582.753
# huckel_kinetic_global_pair_response                              2477.395
# electronegativity_kinetic_global_pair                            2389.700
# huckel_kinetic_response                                           618.328
# electronegativity_kinetic                                          76.818
# electronegativity_kinetic_global_pair_response                   3320.557
# huckel_electronegativity_kinetic                                 2558.195
# huckel_electronegativity_global_pair_response                      37.468
# kinetic_global_pair_response                                     3478.114
#
#                                                     R2 energy (testing)  \
# huckel_global_pair                                                0.048
# huckel_electronegativity_kinetic_global_pair                      0.061
# huckel_electronegativity_kinetic_global_pair_re...                0.031
# huckel_electronegativity_global_pair                              0.075
# global_pair                                                       0.113
# kinetic                                                           0.051
# kinetic_response                                                  0.051
# response                                                          0.043
# electronegativity_global_pair                                     0.094
# electronegativity_response                                        0.017
# electronegativity                                                 0.019
# global_pair_response                                              0.119
# huckel                                                            0.028
# huckel_response                                                   0.028
# huckel_electronegativity                                          0.001
# huckel_electronegativity_response                                 0.001
# huckel_kinetic_global_pair                                        0.000
# huckel_electronegativity_kinetic_response                         0.001
# huckel_kinetic                                                    0.002
# electronegativity_kinetic_response                                0.000
# electronegativity_global_pair_response                            0.007
# kinetic_global_pair                                               0.000
# huckel_global_pair_response                                       0.000
# huckel_kinetic_global_pair_response                               0.003
# electronegativity_kinetic_global_pair                             0.013
# huckel_kinetic_response                                           0.004
# electronegativity_kinetic                                         0.006
# electronegativity_kinetic_global_pair_response                    0.007
# huckel_electronegativity_kinetic                                  0.000
# huckel_electronegativity_global_pair_response                     0.003
# kinetic_global_pair_response                                      0.000
#
#                                                     R2 dipole (testing)  \
# huckel_global_pair                                                0.270
# huckel_electronegativity_kinetic_global_pair                      0.263
# huckel_electronegativity_kinetic_global_pair_re...                0.261
# huckel_electronegativity_global_pair                              0.246
# global_pair                                                       0.223
# kinetic                                                           0.218
# kinetic_response                                                  0.218
# response                                                          0.217
# electronegativity_global_pair                                     0.216
# electronegativity_response                                        0.213
# electronegativity                                                 0.213
# global_pair_response                                              0.209
# huckel                                                            0.203
# huckel_response                                                   0.203
# huckel_electronegativity                                          0.203
# huckel_electronegativity_response                                 0.201
# huckel_kinetic_global_pair                                        0.025
# huckel_electronegativity_kinetic_response                         0.015
# huckel_kinetic                                                    0.012
# electronegativity_kinetic_response                                0.011
# electronegativity_global_pair_response                            0.009
# kinetic_global_pair                                               0.008
# huckel_global_pair_response                                       0.007
# huckel_kinetic_global_pair_response                               0.006
# electronegativity_kinetic_global_pair                             0.005
# huckel_kinetic_response                                           0.004
# electronegativity_kinetic                                         0.003
# electronegativity_kinetic_global_pair_response                    0.001
# huckel_electronegativity_kinetic                                  0.001
# huckel_electronegativity_global_pair_response                     0.001
# kinetic_global_pair_response                                      0.000
#
#                                                     obj. func. (testing)
# huckel_global_pair                                              0.729755
# huckel_electronegativity_kinetic_global_pair                    0.736617
# huckel_electronegativity_kinetic_global_pair_re...              0.738872
# huckel_electronegativity_global_pair                            0.754368
# global_pair                                                     0.777340
# kinetic                                                         0.781999
# kinetic_response                                                0.781999
# response                                                        0.783363
# electronegativity_global_pair                                   0.783943
# electronegativity_response                                      0.786931
# electronegativity                                               0.786539
# global_pair_response                                            0.791009
# huckel                                                          0.797212
# huckel_response                                                 0.797117
# huckel_electronegativity                                        0.797492
# huckel_electronegativity_response                               0.798564
# huckel_kinetic_global_pair                                      0.975038
# huckel_electronegativity_kinetic_response                       0.984898
# huckel_kinetic                                                  0.987519
# electronegativity_kinetic_response                              0.989384
# electronegativity_global_pair_response                          0.991287
# kinetic_global_pair                                             0.992455
# huckel_global_pair_response                                     0.993314
# huckel_kinetic_global_pair_response                             0.994085
# electronegativity_kinetic_global_pair                           0.995157
# huckel_kinetic_response                                         0.995630
# electronegativity_kinetic                                       0.996911
# electronegativity_kinetic_global_pair_response                  0.999323
# huckel_electronegativity_kinetic                                0.998751
# huckel_electronegativity_global_pair_response                   0.998695
# kinetic_global_pair_response                                    0.999607
